# %% [markdown]
# # **Tutorial to learn `graphviz` tool**

# %% [markdown]
# ### `graphviz` is a graph visualization open source tool which is used for creating flowcharts, diagrams, and networks.
#
# ### [Click Here to know more](https://graphviz.org/)
#
# ### Following are the steps to make flowcharts:
#
# #### **Step 1:** Install `graphviz` tool
# #### **Step 2:** Import supporting libraries
# #### **Step 3:** Create a directed graph with nodes and edges
#
# ### **Useful Informations**
#
# - #### [Different Node Shapes](https://graphviz.org/doc/info/shapes.html)
# - #### [List of Edge Attributes](https://graphviz.org/docs/edges/)
# - #### [Color names](https://graphviz.org/doc/info/colors.html)
# - #### [Arrow Shapes](https://graphviz.org/doc/info/arrows.html)
# - #### [Frequently Asked Questions](https://graphviz.org/faq/)

# %% [markdown]
# # Step 1: Install `graphviz` library

# %%
# !apt-get install -y graphviz
# !pip install graphviz
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# ...

# %% [markdown]
# # Step 2: Import necessary libraries

# %%
from graphviz import Digraph
from IPython.display import SVG

# %% [markdown]
# # Step 3: Create a Digraph (Directed Graph)
#
# Example: Here the hierarchical layout of reports from IPCC has been displayed.
# ### Note: Nodes and edges can be changed according to your data.

# %%
# Create a Digraph (Directed Graph)
dot = Digraph()

# Add nodes with colored boxes, borders, and clickable URLs
dot.node('A', 'IPCC ar6 reports', href='https://www.ipcc.ch/', style='filled', fillcolor='lightblue', color='black', shape='box')
dot.node('B', 'wg1', href='https://www.ipcc.ch/report/ar6/wg1/', style='filled', fillcolor='pink', color='black', shape='box')
dot.node('C', 'wg2', href='https://www.ipcc.ch/report/ar6/wg2/', style='filled', fillcolor='pink', color='black', shape='box')
dot.node('D', 'wg3', href='https://www.ipcc.ch/report/ar6/wg3/', style='filled', fillcolor='pink', color='black', shape='box')
dot.node('E', 'Chapter-4', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/', style='filled', fillcolor='yellow', color='black', shape='box')
dot.node('F', 'srccl', href='https://www.ipcc.ch/srccl/', style='filled', fillcolor='aquamarine', color='black', shape='box')
dot.node('G', 'srocc', href='https://www.ipcc.ch/srocc/', style='filled', fillcolor='gainsboro', color='black', shape='box')
dot.node('H', 'syr', href='https://www.ipcc.ch/report/ar6/syr/', style='filled', fillcolor='cornsilk', color='black', shape='box')
dot.node('a', '4.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.1',  style='filled', fillcolor='orange', color='black', shape='box')
dot.node('b', '4.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2', style='filled', fillcolor='orange',  color='black', shape='box')
dot.node('c', '4.3', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.3', style='filled', fillcolor='orange',  color='black', shape='box')
dot.node('d', '4.4', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4', style='filled', fillcolor='orange',  color='black', shape='box')
dot.node('e', '4.5', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.5', style='filled', fillcolor='orange',  color='black', shape='box')
dot.node('f', '4.6', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.6', style='filled', fillcolor='orange',  color='black', shape='box')
dot.node('g', '4.7', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.7', style='filled', fillcolor='orange',  color='black', shape='box')
dot.node('h', '4.8', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.8', style='filled', fillcolor='orange',  color='black', shape='box')
dot.node('a1', '4.1.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.1.1',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('a2', '4.1.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.1.2', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('b1', '4.2.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2.1',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('b2', '4.2.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2.2',style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('b3', '4.2.3', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2.3',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('b4', '4.2.4', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2.4',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('b5', '4.2.5', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2.5',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('b6', '4.2.6', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2.6',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('b7', '4.2.7', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2.7',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('b8', '4.2.8', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2.8',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('c1', '4.3.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.3.1',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('c2', '4.3.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.3.2', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('c3', '4.3.3', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.3.3',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('c4', '4.3.4', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.3.4',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('c5', '4.3.5', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.3.5', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('c6', '4.3.6', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.3.6', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('c7', '4.3.7', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.3.7', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('c8', '4.3.8', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.3.8', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('d1', '4.4.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4.1',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('d2', '4.4.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4.2',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('d3', '4.4.3', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4.3',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('d4', '4.4.4', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4.4',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('d5', '4.4.5', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4.5',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('d6', '4.4.6', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4.6',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('d7', '4.4.7', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4.7', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('d8', '4.4.8', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4.8',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('e1', '4.5.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.5.1', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('e2', '4.5.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.5.2', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('e2', '4.5.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.5.2', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('e3', '4.5.3', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.5.3', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('e4', '4.5.4', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.5.4', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('e5', '4.5.5', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.5.5', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('e6', '4.5.6', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.5.6', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('e7', '4.5.7', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.5.7',style='filled', fillcolor='lightgreen' ,color='black', shape='ellipse')
dot.node('e8', '4.5.8', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.5.8', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('f1', '4.6.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.6.1', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('f2', '4.6.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.6.2',style='filled', fillcolor='lightgreen' ,color='black', shape='ellipse')
dot.node('f3', '4.6.3', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.6.3', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('f4', '4.6.4', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.6.4', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('f5', '4.6.5', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.6.5', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('f6', '4.6.6', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.6.6', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('f7', '4.6.7', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.6.7',style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('f8', '4.6.8', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.6.8',style='filled', fillcolor='lightgreen' ,color='black', shape='ellipse')
dot.node('f9', '4.6.9', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.6.9', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('g1', '4.7.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.7.1', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('g2', '4.7.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.7.2', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('g3', '4.7.3', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.7.3', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('g4', '4.7.4', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.7.4', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('g5', '4.7.5', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.7.5',style='filled', fillcolor='lightgreen' ,color='black', shape='ellipse')
dot.node('g6', '4.7.6', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.7.6', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('h1', '4.8.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.8.1', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('h2', '4.8.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.8.2', style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('h3', '4.8.3', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4..3',  style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('h4', '4.8.4', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.8.4', style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('h5', '4.8.5', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.8.5', style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('h6', '4.8.6', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.8.6', style='filled', fillcolor='lightgreen', color='black', shape='ellipse')
dot.node('h7', '4.8.7', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.8.7',  style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('b11', '4.2.1.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2.1.1', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('b12','4.2.1.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2.1.2', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('b13','4.2.1.3', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2.1.3', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('d11','4.4.1.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4.1.1', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('d12','4.4.1.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4.1.2', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('d13','4.4.1.3', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4.1.3', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('g11','4.7.1.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.7.1.1', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('g12','4.7.1.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.7.1.2', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')





# Add edges
dot.edge('A', 'B', color='black')
dot.edge('A', 'C', color='black')
dot.edge('A', 'D', color='black')
dot.edge('C', 'E', color='black')
dot.edge('A', 'F', color='black')
dot.edge('A', 'G', color='black')
dot.edge('A', 'H', color='black')
dot.edge('E', 'a', color='brown', arrowhead='vee', style='dashed')
dot.edge('E', 'b', color='brown', arrowhead='vee', style='dashed')
dot.edge('E', 'c', color='brown', arrowhead='vee', style='dashed')
dot.edge('E', 'd', color='brown', arrowhead='vee', style='dashed')
dot.edge('E', 'e', color='brown', arrowhead='vee', style='dashed')
dot.edge('E', 'f', color='brown', arrowhead='vee', style='dashed')
dot.edge('E', 'g', color='brown', arrowhead='vee', style='dashed')
dot.edge('E', 'h', color='brown', arrowhead='vee', style='dashed')
dot.edge('a', 'a1', color='brown', arrowhead='vee', style='dashed')
dot.edge('a', 'a2', color='brown', arrowhead='vee', style='dashed')
dot.edge('b', 'b1', color='brown', arrowhead='vee', style='dashed')
dot.edge('b', 'b2', color='brown', arrowhead='vee', style='dashed')
dot.edge('b', 'b3', color='brown', arrowhead='vee', style='dashed')
dot.edge('b', 'b4', color='brown', arrowhead='vee', style='dashed')
dot.edge('b', 'b5', color='brown', arrowhead='vee', style='dashed')
dot.edge('b', 'b6', color='brown', arrowhead='vee', style='dashed')
dot.edge('b', 'b7', color='brown', arrowhead='vee', style='dashed')
dot.edge('b', 'b8', color='brown', arrowhead='vee', style='dashed')
dot.edge('c', 'c1', color='brown', arrowhead='vee', style='dashed')
dot.edge('c', 'c2', color='brown', arrowhead='vee', style='dashed')
dot.edge('c', 'c3', color='brown', arrowhead='vee', style='dashed')
dot.edge('c', 'c4', color='brown', arrowhead='vee', style='dashed')
dot.edge('c', 'c5', color='brown', arrowhead='vee', style='dashed')
dot.edge('c', 'c6', color='brown', arrowhead='vee', style='dashed')
dot.edge('c', 'c7', color='brown', arrowhead='vee', style='dashed')
dot.edge('c', 'c8', color='brown', arrowhead='vee', style='dashed')
dot.edge('d', 'd1', color='brown', arrowhead='vee', style='dashed')
dot.edge('d', 'd2', color='brown', arrowhead='vee', style='dashed')
dot.edge('d', 'd3', color='brown', arrowhead='vee', style='dashed')
dot.edge('d', 'd4', color='brown', arrowhead='vee', style='dashed')
dot.edge('d', 'd5', color='brown', arrowhead='vee', style='dashed')
dot.edge('d', 'd6', color='brown', arrowhead='vee', style='dashed')
dot.edge('d', 'd7', color='brown', arrowhead='vee', style='dashed')
dot.edge('d', 'd8', color='brown', arrowhead='vee', style='dashed')
dot.edge('e', 'e1', color='brown', arrowhead='vee', style='dashed')
dot.edge('e', 'e2', color='brown', arrowhead='vee', style='dashed')
dot.edge('e', 'e3', color='brown', arrowhead='vee', style='dashed')
dot.edge('e', 'e4', color='brown', arrowhead='vee', style='dashed')
dot.edge('e', 'e5', color='brown', arrowhead='vee', style='dashed')
dot.edge('e', 'e6', color='brown', arrowhead='vee', style='dashed')
dot.edge('e', 'e7', color='brown', arrowhead='vee', style='dashed')
dot.edge('e', 'e8', color='brown', arrowhead='vee', style='dashed')
dot.edge('f', 'f1', color='brown', arrowhead='vee', style='dashed')
dot.edge('f', 'f2', color='brown', arrowhead='vee', style='dashed')
dot.edge('f', 'f3', color='brown', arrowhead='vee', style='dashed')
dot.edge('f', 'f4', color='brown', arrowhead='vee', style='dashed')
dot.edge('f', 'f5', color='brown', arrowhead='vee', style='dashed')
dot.edge('f', 'f6', color='brown', arrowhead='vee', style='dashed')
dot.edge('f', 'f7', color='brown', arrowhead='vee', style='dashed')
dot.edge('f', 'f8', color='brown', arrowhead='vee', style='dashed')
dot.edge('f', 'f9', color='brown', arrowhead='vee', style='dashed')
dot.edge('g', 'g1', color='brown', arrowhead='vee', style='dashed')
dot.edge('g', 'g2', color='brown', arrowhead='vee', style='dashed')
dot.edge('g', 'g3', color='brown', arrowhead='vee', style='dashed')
dot.edge('g', 'g4', color='brown', arrowhead='vee', style='dashed')
dot.edge('g', 'g5', color='brown', arrowhead='vee', style='dashed')
dot.edge('g', 'g6', color='brown', arrowhead='vee', style='dashed')
dot.edge('h', 'h1', color='brown', arrowhead='vee', style='dashed')
dot.edge('h', 'h2', color='brown', arrowhead='vee', style='dashed')
dot.edge('h', 'h3', color='brown', arrowhead='vee', style='dashed')
dot.edge('h', 'h4', color='brown', arrowhead='vee', style='dashed')
dot.edge('h', 'h5', color='brown', arrowhead='vee', style='dashed')
dot.edge('h', 'h6', color='brown', arrowhead='vee', style='dashed')
dot.edge('h', 'h7', color='brown', arrowhead='vee', style='dashed')
dot.edge('b1', 'b11', color='brown', arrowhead='vee', style='dashed')
dot.edge('b1', 'b12', color='brown', arrowhead='vee', style='dashed')
dot.edge('b1', 'b13', color='brown', arrowhead='vee', style='dashed')
dot.edge('d1', 'd11', color='brown', arrowhead='vee', style='dashed')
dot.edge('d1', 'd12', color='brown', arrowhead='vee', style='dashed')
dot.edge('d1', 'd13', color='brown', arrowhead='vee', style='dashed')
dot.edge('g1', 'g11', color='brown', arrowhead='vee', style='dashed')
dot.edge('g1', 'g12', color='brown', arrowhead='vee', style='dashed')


# dot.edge('B', 'D', 'Signal', color='green')

# Save the graph as an SVG file
output_file = 'ipcc_ch04_graph'
dot.render(output_file, format='svg', cleanup=True)

# Display the graph
SVG(filename=f'{output_file}.svg')

# %%
from graphviz import Digraph
from IPython.display import SVG

# Create a Digraph (Directed Graph)
dot = Digraph()

# Add base nodes
dot.node('A', 'IPCC ar6 reports', href='https://www.ipcc.ch/', style='filled', fillcolor='lightblue', color='black', shape='box')
dot.node('B', 'wg1', href='https://www.ipcc.ch/report/ar6/wg1/', style='filled', fillcolor='pink', color='black', shape='box')
dot.node('C', 'wg2', href='https://www.ipcc.ch/report/ar6/wg2/', style='filled', fillcolor='pink', color='black', shape='box')
dot.node('D', 'wg3', href='https://www.ipcc.ch/report/ar6/wg3/', style='filled', fillcolor='pink', color='black', shape='box')
dot.node('E', 'Chapter-4', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/', style='filled', fillcolor='yellow', color='black', shape='box')
dot.node('F', 'srccl', href='https://www.ipcc.ch/srccl/', style='filled', fillcolor='aquamarine', color='black', shape='box')
dot.node('G', 'srocc', href='https://www.ipcc.ch/srocc/', style='filled', fillcolor='gainsboro', color='black', shape='box')
dot.node('H', 'syr', href='https://www.ipcc.ch/report/ar6/syr/', style='filled', fillcolor='cornsilk', color='black', shape='box')

# Add nodes for chapter sections using a loop
chapter_sections = ['4.1', '4.2', '4.3', '4.4', '4.5', '4.6', '4.7', '4.8']
for i, section in enumerate(chapter_sections):
    node_name = chr(ord('a') + i)  # Generate node names 'a', 'b', 'c', etc.
    href = f'https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#{section}'
    dot.node(node_name, section, href=href, style='filled', fillcolor='orange', color='black', shape='box')

# Add nodes for sub-sections using nested loops
sub_sections = {
    'a': range(1, 3),
    'b': range(1, 9),
    'c': range(1, 9),
    'd': range(1, 9),
    'e': range(1, 9),
    'f': range(1, 10),
    'g': range(1, 7),
    'h': range(1, 8)
}

for section_node, num_subsections in sub_sections.items():
  for i in num_subsections:
    sub_section_name = f'{section_node}{i}'
    sub_section_label = f'4.{ord(section_node) - ord("a") + 1}.{i}'
    href = f'https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#{sub_section_label}'
    dot.node(sub_section_name, sub_section_label, href=href, style='filled', fillcolor='lightgreen', color='black', shape='ellipse')

# Add nodes for sub-sub-sections (these were added individually in your original code)
dot.node('b11', '4.2.1.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2.1.1', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('b12','4.2.1.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2.1.2', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('b13','4.2.1.3', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.2.1.3', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('d11','4.4.1.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4.1.1', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('d12','4.4.1.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4.1.2', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('d13','4.4.1.3', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.4.1.3', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('g11','4.7.1.1', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.7.1.1', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')
dot.node('g12','4.7.1.2', href='https://www.ipcc.ch/report/ar6/wg2/chapter/chapter-4/#4.7.1.2', style='filled', fillcolor='lightgreen',color='black', shape='ellipse')


# Add edges for base connections
dot.edge('A', 'B', color='black')
dot.edge('A', 'C', color='black')
dot.edge('A', 'D', color='black')
dot.edge('C', 'E', color='black')
dot.edge('A', 'F', color='black')
dot.edge('A', 'G', color='black')
dot.edge('A', 'H', color='black')

# Add edges from Chapter-4 to chapter sections using a loop
for i in range(len(chapter_sections)):
    dot.edge('E', chr(ord('a') + i), color='brown', arrowhead='vee', style='dashed')

# Add edges from chapter sections to sub-sections using nested loops
for section_node, num_subsections in sub_sections.items():
    for i in num_subsections:
        sub_section_name = f'{section_node}{i}'
        dot.edge(section_node, sub_section_name, color='brown', arrowhead='vee', style='dashed')

# Add edges from sub-sections to sub-sub-sections (these were added individually in your original code)
dot.edge('b1', 'b11', color='brown', arrowhead='vee', style='dashed')
dot.edge('b1', 'b12', color='brown', arrowhead='vee', style='dashed')
dot.edge('b1', 'b13', color='brown', arrowhead='vee', style='dashed')
dot.edge('d1', 'd11', color='brown', arrowhead='vee', style='dashed')
dot.edge('d1', 'd12', color='brown', arrowhead='vee', style='dashed')
dot.edge('d1', 'd13', color='brown', arrowhead='vee', style='dashed')
dot.edge('g1', 'g11', color='brown', arrowhead='vee', style='dashed')
dot.edge('g1', 'g12', color='brown', arrowhead='vee', style='dashed')

# Save the graph as an SVG file
output_file = 'ipcc_ch04_graph'
dot.render(output_file, format='svg', cleanup=True)

# Display the graph
SVG(filename=f'{output_file}.svg')

# %% [markdown]
# ## Reference:
#
# Ellson, J., Gansner, E. R., Koutsofios, E., & North, S. (2001). Graphviz - Graph visualization software. AT&T Labs Research. Retrieved from https://graphviz.gitlab.io/

# %% [markdown]
# ### This Colab Notebook contain graphviz for chapter 04
