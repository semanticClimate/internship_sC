# %% [markdown]
# <a href="https://colab.research.google.com/github/semanticClimate/internship_sC/blob/sharon/CCP7Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --quiet amilib==0.3.9
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.0/324.0 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 70.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.8/87.8 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 77.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 33.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 98.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 22.5 MB/s eta 0:00:00
# ...

# %%
# !amilib DICT --words /content/wordlist.txt --description wikipedia wiktionary --dict ccpforest.html --operation create  --figures
# Out:
# INFO amix.py:555:***** amilib VERSION 0.3.9 *****
# INFO:amilib.amix:***** amilib VERSION 0.3.9 *****
# INFO amix.py:170:command: ['DICT', '--words', '/content/wordlist.txt', '--description', 'wikipedia', 'wiktionary', '--dict', 'ccpforest.html', '--operation', 'create', '--figures']
# INFO:amilib.amix:command: ['DICT', '--words', '/content/wordlist.txt', '--description', 'wikipedia', 'wiktionary', '--dict', 'ccpforest.html', '--operation', 'create', '--figures']
# DEBUG dict_args.py:52:creating HTML Args
# DEBUG:amilib.dict_args:creating HTML Args
# DEBUG dict_args.py:52:creating HTML Args
# DEBUG:amilib.dict_args:creating HTML Args
# DEBUG dict_args.py:123:DICT process_args {'version': False, 'command': 'DICT', 'description': ['wikipedia', 'wiktionary'], 'dict': 'ccpforest.html', 'figures': [], 'operation': 'create', 'title': 'unknown', 'validate': False, 'words': '/content/wordlist.txt'}
# ...

# %%
from IPython.core.display import display, HTML

# Path to the HTML file
html_file_path = '/content/ccpforest.html'

# Read the HTML file
with open(html_file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Display the HTML content
display(HTML(html_content))
# Out:
# <html><head><style>div[role] {border:solid 1px;margin:1px;}</style><base href="https://en.wikipedia.org/wiki/"></head><body><div role="ami_dictionary" title="ccpforest"><div name="forest" term="forest" role="ami_entry"><p>search term:  forest <a href="https://en.wikipedia.org/w/index.php?search=forest">Wikipedia Page</a></p><p class="wpage_first_para">A <b>forest</b> is an <a href="/wiki/Ecosystem" title="Ecosystem">ecosystem</a> characterized by a dense <a href="/wiki/Ecological_community" class="mw-redirect" title="Ecological community">community</a> of <a href="/wiki/Tree" title="Tree">trees</a>.<sup id="cite_ref-2" class="reference"><a href="#cite_note-2"><span class="cite-bracket">[</span>2<span class="cite-bracket">]</span></a></sup> Hundreds of definitions of forest are used throughout the world, incorporating factors such as tree density, tree height, land use, legal standing, and ecological function.<sup id="cite_ref-3" class="reference"><a href="#cite_note-3"><span class="c
# ...
