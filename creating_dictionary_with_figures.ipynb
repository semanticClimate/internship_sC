# %% [markdown]
# ## **Aim: Creating Wikimedia enhanced dictionary with #semanticClimate tool `amilib`**
# `amilib` is a code library for processing documents. `amilib` tools can be used for finding, cleaning, converting, searching, republishing legacy documents.
#
# ### **Why are we doing this?**
#
# The climate reports or any other documents that contains the difficult or technical terms that are not easy to understand can be made understandable with Wikimedia enhanced dictionary.
#
# ### **Workflow**
# This colab has been created to make **dictionary from the wordlists**. Following are the steps to create HTML format of the dictionary.
#
# - **Step 1:** Installation of the tool `amilib` in the colab environment.
# - **Step 2:** This step involves uploading text file having wordlist from the local system into the colab content folder (left side panel). The path of the text file should be edited in the code to run the code to create dictionary in HTML format.

# %% [markdown]
# ![words_dict.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **Step 1: Installation of the tool `amilib` in colab environment.**
#
# - To install `amilib`, run the code `!pip install amilib==0.3.9` by clicking on the play button in square bracket in the following code cell.
#
# - This will take 1-2 minutes to install.

# %%
# !pip install --quiet amilib==0.3.9
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.0/324.0 kB 5.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 47.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.8/87.8 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 68.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 36.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 84.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.3/301.3 kB 18.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Step 2: Creating dictionary in HTML format from the wordlist.**
#
# The following code reads a list of words, looks up the Wikipedia entries and creates a dictionary.
#
# - This step involves uploading text file having wordlist from the local system into the colab files (left side panel).
#
# - The path of the text file should be edited in the code to run the code to create dictionary in HTML format.
#
# - Example: the path of the input text file in the following code is `/content/words_wg1chap03.txt`
#
# - the output file name is `wg1chap03_dict.html`. The file name can be changed.
#
# - The output file can be downloaded from the colab to the local system.(Click on three vertical dots to see download option form the files in the left side panel).

# %%
# !amilib DICT --words /content/words_wg2chap04.txt --description wikipedia --dict wg2chap04_dict.html --figures --operation create
# Out:
# INFO amix.py:555:***** amilib VERSION 0.3.9 *****
# INFO:amilib.amix:***** amilib VERSION 0.3.9 *****
# INFO amix.py:170:command: ['DICT', '--words', '/content/words_wg2chap04.txt', '--description', 'wikipedia', '--dict', 'wg2chap04_dict.html', '--figures', '--operation', 'create']
# INFO:amilib.amix:command: ['DICT', '--words', '/content/words_wg2chap04.txt', '--description', 'wikipedia', '--dict', 'wg2chap04_dict.html', '--figures', '--operation', 'create']
# DEBUG dict_args.py:52:creating HTML Args
# DEBUG:amilib.dict_args:creating HTML Args
# DEBUG dict_args.py:52:creating HTML Args
# DEBUG:amilib.dict_args:creating HTML Args
# DEBUG dict_args.py:123:DICT process_args {'version': False, 'command': 'DICT', 'description': 'wikipedia', 'dict': 'wg2chap04_dict.html', 'figures': [], 'operation': 'create', 'title': 'unknown', 'validate': False, 'words': '/content/words_wg2chap04.txt'}
# ...

# %% [markdown]
# ## **Step 3: Displaying Dictionary (HTML output) in Colab environment**

# %%
from IPython.core.display import display, HTML

# Path to the HTML file
html_file_path = '/content/wg2chap04_dict.html'

# Read the HTML file
with open(html_file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Display the HTML content
display(HTML(html_content))
# Out:
# <html><head><style>div[role] {border:solid 1px;margin:1px;}</style><base href="https://en.wikipedia.org/wiki/"></head><body><div role="ami_dictionary" title="wg2chap04_dict"><div name="Climate Words :" term="Climate Words :" role="ami_entry"><p>search term:  Climate Words : <a href="https://en.wikipedia.org/w/index.php?search=Climate%20Words%20:">Wikipedia Page</a></p><p class="wpage_first_para">
# ...

# %% [markdown]
# ## References and acknowledgements
# 1. [`amilib`](https://github.com/petermr/amilib) (Peter Murray-Rust)
# 2. [Wikimedia](https://www.wikimedia.org/)
# 3. [IPCC](https://www.ipcc.ch/)

# %% [markdown]
# ### **Created by: Renu Kumari**
